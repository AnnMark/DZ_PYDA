# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
len('Насколько проще было бы писать программы, если бы не заказчики') > len('640Кб должно хватить для любых задач. Билл Гейтс (по легенде)')
# Out:
# True

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
print(len(long_phrase) > len(short_phrase))
# Out:
# True

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах (*в мегабайте 2^20 байт*). Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*".

# %%
a = int(input('Введите значение объема файла в байтах: '))
b = 1024**2
c = a / b
print('Объем файла равен' ,c,'Mb')
# Out:
# Введите значение объема файла в байтах: 1048576
# Объем файла равен 1.0 Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
a = input('Введите месяц ')
b = int(input('Введите число '))
if (a == 'декабрь' and 22 <= b <= 31) or (b <= 20 and a == 'январь'):
    print('Козерог') 
elif (a == 'январь' and 21 <= b <= 31) or (b <= 19 and a == 'февраль'):
    print('Водолей')
elif (a == 'февраль' and 20 <= b <= 29) or (b <= 20 and a == 'март'):
    print('Рыбы')
elif (a == 'март' and 21 <= b <= 31) or (b <= 20 and a == 'апрель'):
    print('Овен')
elif (a == 'апрель' and 21 <= b <= 30) or (b <= 21 and a == 'май'):
    print('Телец')
elif (a == 'май' and 22 <= b <= 31) or (b <= 21 and a == 'июнь'):
    print('Близнецы')
elif (a == 'июнь' and 22 <= b <= 30) or (b <= 22 and a == 'июль'):
    print('Рак')
elif (a == 'июль' and 23 <= b <= 31) or (b <= 22 and a == 'август'):
    print('Лев')
elif (a == 'август' and 23 <= b <= 31) or (b <= 22 and a == 'сентябрь'):
    print('Дева')
elif (a == 'сентябрь' and 23 <= b <= 30) or (b <= 22 and a == 'октябрь'):
    print('Весы')
elif (a == 'октябрь' and 23 <= b <= 31) or (b <= 22 and a == 'ноябрь'):
    print('Скорпион')
elif (a == 'ноябрь' and 23 <= b <= 30) or (b <= 21 and a == 'декабрь'):
    print('Стрелец')    
else:
    print('Не корректное значение')
# Out:
# Введите месяц январь
# Введите число 32
# Не корректное значение

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
a = int(input('Введите заработанную плату в месяц: ')) #з/п в рублях
b = int(input('Введите сколько процентов уходит на ипотеку: ')) #ипотека в %
c = int(input('Введите сколько процентов уходит на жизнь: ')) #на жизнь в %
d = int(input('Введите количество премий за год: ')) #кол-во премий в год
x = a * d #сумма премий за год 
z = a * (b / 100) #ипотека 
y = (a - ((b+c) / 100) * a) * 12 + (x / 2) #накоплено в т.ч на пенсию

print('На ипотеку было потрачено:',z,' рублей ','Было накоплено:',y,' рублей ')
# Out:
# Введите заработанную плату в месяц: 10000
# Введите сколько процентов уходит на ипотеку: 10
# Введите сколько процентов уходит на жизнь: 10
# Введите количество премий за год: 1
# На ипотеку было потрачено: 1000.0  рублей  Было накоплено: 101000.0  рублей
